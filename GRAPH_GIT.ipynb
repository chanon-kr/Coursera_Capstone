# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib notebook

# %%
df = pd.DataFrame({'col':np.arange(1,200,1)})

# %%
df.plot()
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="639.9999861283738">
